# %% [markdown]
# # Ramadan Abdunabi
# ## Week 14 - 12/1/2024
# ### Python Data Visualization - Making informative visualizations (using plots).

# %%
# The normal imports
import numpy as np
from numpy.random import randn, random, randint
import pandas as pd
from pandas import Series, DataFrame

# These are the plotting modules and libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
# Plotting Data Using pandas
# Plot Series
ts = Series(randn(100), index=pd.date_range("1/1/2023", periods=100))

ts
# Out:
# 2023-01-01    0.034779
# 2023-01-02    0.403145
# 2023-01-03   -0.449707
# 2023-01-04    0.493767
# 2023-01-05   -0.072542
#                 ...
# 2023-04-06   -0.221449
# 2023-04-07   -0.672096
# 2023-04-08    0.147813
# 2023-04-09   -0.335947
# 2023-04-10   -0.143164
# Freq: D, Length: 100, dtype: float64

# %%
ts.plot()

# %%
# plot DataFrame
df = DataFrame(randn(100, 4)* 10, index=ts.index, columns=list('ABCD'))
df
# Out:
#                     A          B          C          D
# 2023-01-01   9.836542   0.304028  20.598226   5.922871
# 2023-01-02   3.015938  -3.597513 -11.773574  -7.595244
# 2023-01-03   3.525617   3.424834  13.767517 -16.751068
# 2023-01-04   1.365606  -7.199424   1.536411   7.521997
# 2023-01-05   4.264435   8.965419  -3.613592  -5.245263
# ...               ...        ...        ...        ...
# 2023-04-06  -3.201324   1.453806   9.228507  -6.208463
# 2023-04-07   3.139386  12.098620   3.272041 -15.755559
# 2023-04-08  -1.864182  -1.189349  22.418961  16.355784
# 2023-04-09  -1.871365   0.506718   7.363179  -7.830232
# 2023-04-10  19.071300  -3.153999   0.358790  -3.595751
#
# [100 rows x 4 columns]

# %%
df.plot()

# %%
df.plot(x='A',y='B')

# %%
df['E'] = ts.index

# %%
df
# Out:
#                     A          B          C          D          E
# 2023-01-01   9.836542   0.304028  20.598226   5.922871 2023-01-01
# 2023-01-02   3.015938  -3.597513 -11.773574  -7.595244 2023-01-02
# 2023-01-03   3.525617   3.424834  13.767517 -16.751068 2023-01-03
# 2023-01-04   1.365606  -7.199424   1.536411   7.521997 2023-01-04
# 2023-01-05   4.264435   8.965419  -3.613592  -5.245263 2023-01-05
# ...               ...        ...        ...        ...        ...
# 2023-04-06  -3.201324   1.453806   9.228507  -6.208463 2023-04-06
# 2023-04-07   3.139386  12.098620   3.272041 -15.755559 2023-04-07
# 2023-04-08  -1.864182  -1.189349  22.418961  16.355784 2023-04-08
# 2023-04-09  -1.871365   0.506718   7.363179  -7.830232 2023-04-09
# 2023-04-10  19.071300  -3.153999   0.358790  -3.595751 2023-04-10
#
# [100 rows x 5 columns]

# %%
df.plot(x='E',y='A')

# %%
df.hist(column='B')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002589A761188>]],
#       dtype=object)

# %%
df.hist(column='C')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002589A7B2C08>]],
#       dtype=object)

# %%
df.hist(column=['A','C'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002589A897488>,
# ...
#       dtype=object)

# %%
# Plot Data with matplotlib
# Series
s = Series(randn(50))
s
# Out:
# 0    -0.695931
# 1    -0.103086
# 2    -0.870010
# 3    -0.323185
# 4    -0.458035
# 5    -0.354683
# 6     0.055471
# 7     1.107293
# 8     0.393942
# 9    -1.046476
# 10   -0.229754
# 11    1.228347
# 12   -0.303893
# 13    0.609147
# 14   -0.046339
# 15   -0.532085
# 16    0.602886
# 17   -0.953417
# 18   -0.513087
# 19    0.114321
# 20   -0.243489
# 21   -2.435458
# 22    0.612021
# 23    1.890989
# 24    0.202046
# 25   -0.042911
# 26    1.200236
# 27    0.542795
# 28    2.130335
# 29    0.468105
# 30    0.166324
# 31   -0.076413
# 32    1.337674
# 33   -1.377475
# 34   -0.251497
# 35    0.882282
# 36   -0.073249
# 37    0.297771
# 38    1.366769
# 39    1.284673
# 40   -0.917852
# 41    0.862744
# 42    0.975270
# 43    0.017625
# 44   -0.195572
# 45   -0.012636
# 46    0.145242
# 47    0.755960
# 48   -0.476757
# 49   -0.379960
# dtype: float64

# %%
plt.plot(s)

# %%
# DataFrame
df = DataFrame(randn(50).cumsum())
df
# Out:
#             0
# 0    0.593325
# 1    0.603036
# 2    1.429011
# 3    0.616425
# 4    1.658876
# 5    2.252612
# 6    3.495499
# 7    5.447191
# 8    6.628463
# 9    6.465361
# 10   6.910845
# 11   8.452920
# 12   8.777219
# 13   8.921859
# 14   6.899225
# 15   6.185695
# 16   5.758101
# 17   4.909899
# 18   4.766565
# 19   4.728346
# 20   5.331149
# 21   5.840639
# 22   7.600010
# 23   6.844185
# 24   8.278924
# 25   7.477277
# 26   8.773109
# 27   9.975301
# 28  10.129086
# 29   8.699428
# 30   9.656853
# 31   8.968979
# 32   9.260289
# 33   9.127466
# 34   8.809296
# 35   9.425050
# 36   9.045317
# 37   9.993844
# 38  10.181977
# 39  11.350364
# 40  10.134225
# 41   9.504164
# 42   7.118363
# 43   6.677920
# 44   7.092309
# 45   6.807833
# 46   6.018880
# 47   6.136407
# 48   6.932969
# 49   7.989865

# %%
plt.plot(df)

# %%
df.min()
# Out:
# 0    0.593325
# dtype: float64

# %%
df.max()
# Out:
# 0    11.350364
# dtype: float64

# %%
plt.hist(randn(100))
# Out:
# (array([ 3.,  0., 11., 13., 25., 16., 11., 10.,  8.,  3.]),
#  array([-2.46197381, -1.95587132, -1.44976882, -0.94366633, -0.43756383,
#          0.06853866,  0.57464116,  1.08074365,  1.58684615,  2.09294864,
#          2.59905114]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(randn(100), color='indianred')
# Out:
# (array([ 3.,  2., 15., 18., 20., 19., 12.,  7.,  2.,  2.]),
#  array([-2.59813886, -2.07363865, -1.54913844, -1.02463823, -0.50013802,
#          0.0243622 ,  0.54886241,  1.07336262,  1.59786283,  2.12236304,
#          2.64686325]),
#  <a list of 10 Patch objects>)

# %%
dataset1 = randn(100)
dataset2 = randn(50)
plt.hist(dataset1, color='indianred',alpha=0.7, bins=20)
plt.hist(dataset2, alpha=0.7,bins=20)
# Out:
# (array([1., 2., 1., 2., 0., 8., 2., 5., 3., 5., 2., 4., 3., 3., 5., 0., 1.,
#         1., 1., 1.]),
#  array([-2.71263265, -2.46917827, -2.22572389, -1.98226952, -1.73881514,
#         -1.49536076, -1.25190638, -1.008452  , -0.76499763, -0.52154325,
#         -0.27808887, -0.03463449,  0.20881989,  0.45227427,  0.69572864,
#          0.93918302,  1.1826374 ,  1.42609178,  1.66954616,  1.91300053,
#          2.15645491]),
#  <a list of 20 Patch objects>)

# %%
# Figures and Subplots
fig = plt.figure(figsize = (2,4), dpi=100)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot(randn(10)*10)

ax2 = fig.add_subplot(2,2,2)
plt.plot(np.random.random(10)*10)

ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randint(1,100, size=10))

ax4 = fig.add_subplot(2,2,4)
plt.plot(randn(10)*50)

# %%
#line and color style
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
plt.plot(randn(10)*10)

ax2 = fig.add_subplot(2,2,2)
plt.plot(np.random.random(10)*10)

ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randint(1,100, size=10), 'k.')

ax4 = fig.add_subplot(2,2,4)
plt.plot(randn(10)*50, 'k--')

# %%
fig = plt.figure(figsize = (8,10), dpi=100)
dataset = randn(50).cumsum()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
ax1.plot(dataset, 'k--')
ax2.hist(dataset, bins=20, color='k', alpha=0.25)
ax3.scatter(dataset,dataset.cumsum())
ax4.plot(dataset,'ko--')
fig

# %%
plt.plot(randn(30),'ko--')

# %%
plt.plot(4 * randn(30), color='red', linestyle='dotted', marker='o')

# %%
plt.plot(4 * randn(30), color='blue', linestyle='solid', marker='o')# 'dashed'

# %%
plt.plot(randn(30).cumsum(), drawstyle='steps-post')

# %%
data= randn(30).cumsum()
plt.plot(data, 'k-', drawstyle='steps-post')
plt.plot(data, 'k--')

# %%
#using labels
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.plot(data, 'k--', label='dashed-line')
plt.legend(loc='best') # Place a legend on the axes.locs = ["upper left", "lower left", "center right"]

# %%
#using labels
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.plot(data, 'k--', label='dashed-line')
plt.legend(loc="upper left") # Place a legend on the axes.locs = ["upper left", "lower left", "center right"]

# %%
# plot multiple columns
data = {
    'col1': np.random.randint(1,21, size=20),
    'col2': np.random.randint(20,41, size=20),
    'col3': randn(20),
    'col4': randn(20).cumsum()
      
}

df = DataFrame(data)
df
# Out:
#     col1  col2      col3      col4
# 0     10    35  0.982785  1.895030
# 1     10    37 -0.871291  1.530975
# 2      8    35  0.101330  2.560420
# 3      2    34  0.648736  1.642042
# 4     14    36 -1.869669  0.361496
# 5     18    20 -0.594364  0.622216
# 6      1    38  1.409071  0.447388
# 7      1    38 -0.427867  1.550480
# 8      9    29 -1.516680  0.804657
# 9     17    34 -1.433766 -0.165357
# 10     6    34  0.667192  0.650713
# 11    17    35  0.406354 -0.935505
# 12    13    27  0.340152 -0.238696
# 13     5    33 -0.755147  1.055964
# 14    17    20  1.202401  0.005452
# 15     8    28  0.298043 -1.553369
# 16    11    20 -0.335614 -1.831220
# 17     6    27 -0.402748 -0.256979
# 18     9    37  0.644620 -1.701088
# 19    14    40  0.106876 -1.056580

# %%
plt.plot(df)
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.

# %%
df.plot()

# %%
plt.plot(df['col1'],'k.', label='col1')
plt.plot(df['col2'], 'ko--', label='col2')
plt.legend(loc='best')

# %%
plt.hist(df['col3'])
# Out:
# (array([1., 2., 0., 3., 3., 0., 5., 3., 1., 2.]),
#  array([-1.86966926, -1.54179522, -1.21392118, -0.88604714, -0.5581731 ,
#         -0.23029906,  0.09757498,  0.42544902,  0.75332306,  1.0811971 ,
#          1.40907114]),
#  <a list of 10 Patch objects>)

# %%
#Ticks, Labels, and Legends
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum(), label='Random Data')

# %%
#ticks
ax.set_xticks(list(range(0,1001,250)))


#labels
ax.set_xticklabels(['one','two','three','four','five'], rotation=30, fontsize='small')

# title
ax.set_title('My First Matplotlip Plot with Ticks')

#labels for x and y
ax.set_xlabel('Stages')
ax.set_ylabel('Values')

ax.legend(loc='best')

fig

# %%
#Use dictionary for title, xlabel, and ylabel
props ={'title': 'My First Matplotlip Plot with Ticks',
        'xlabel': 'Stages',
        'ylabel': 'Values'}

ax.set(**props)
fig

# %%
fig.savefig('fig.png')

# %% [markdown]
# # Ramadan Abdunabi
# ## Week 15 - 12/1/2020
# ### Python Data Visualization - Making informative visualizations (using plots).

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# These are the plotting modules and libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
# import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
data = np.arange(5)
data
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(data)

# %%
data = randn(20)
data
# Out:
# array([ 0.04446937,  0.21263702,  1.23152364,  1.03279068,  0.55069513,
#        -0.48905201,  1.06923577, -0.03095936, -1.01411817,  1.78885748,
#        -0.57456471,  0.27540221,  0.74285156,  1.28507291, -0.18557119,
#        -1.37348368, -0.17697248, -1.10451523,  0.23629323, -0.25515638])

# %%
plt.plot(data)

# %%
dataset1 = randn(100)
dataset1
# Out:
# array([ 0.50762579,  1.77432789, -0.80414439,  0.47504163, -0.78598447,
#        -1.11638098,  1.16765254, -0.46687218,  0.30282133,  0.88614805,
#        -1.75852252,  0.35946513,  2.03220206, -2.58744944, -0.42857917,
#        -0.4630353 ,  1.41890889, -1.14588097, -0.63440701, -0.85681883,
#        -0.11195631, -0.37845937, -0.53507633,  0.68529971,  0.72526601,
#         1.13926182,  0.61469908, -0.37160915,  0.09550824, -1.17484628,
#        -0.67166364, -0.52953189,  1.22523297, -1.54579216,  0.72880651,
#         0.0884307 , -0.60879017, -2.00630324, -0.03841885,  2.63825403,
#        -0.70781605,  0.79902021,  0.90884665,  0.7860788 ,  2.0654523 ,
#        -0.92507416, -0.60348024,  0.41095359, -0.19564098, -1.41308445,
#         0.01630986,  1.07473475, -0.57859909, -1.86321751, -1.65281775,
#        -0.53856627, -0.85933297,  0.30392104,  0.51925802,  0.75142907,
#         0.74304245,  1.84445413, -0.26081874,  0.58708427,  0.07131848,
#         0.74121381, -0.72069272,  1.21006815, -0.57733849, -0.76619897,
#        -0.13621464,  0.19128816,  0.87632786, -0.25104251, -0.49021961,
#         0.39223827, -0.61255644,  0.19627554,  0.86990916,  1.02338814,
#         0.0269072 ,  1.25234348,  1.9450862 , -0.74177236,  1.30617554,
#        -1.01373951, -1.42757761,  0.14655938, -1.51119586, -1.77519755,
#        -0.78953103,  1.02388766,  0.01228531, -0.13925092, -0.1260868 ,
#         0.36292556,  1.01698829,  0.40968106,  0.49465483, -1.17928944])

# %%
plt.hist(dataset1)
# Out:
# (array([ 1.,  6.,  7., 21., 16., 18., 17.,  8.,  5.,  1.]),
#  array([-2.58744944, -2.06487909, -1.54230874, -1.0197384 , -0.49716805,
#          0.0254023 ,  0.54797264,  1.07054299,  1.59311334,  2.11568369,
#          2.63825403]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 4.,  4.,  9., 10., 15., 18., 11.,  7.,  1.,  1.]),
#  array([-2.49345746, -1.96366193, -1.43386639, -0.90407086, -0.37427532,
#          0.15552021,  0.68531574,  1.21511128,  1.74490681,  2.27470235,
#          2.80449788]),
#  <a list of 10 Patch objects>)

# %%
# We can use normed to plot on same plot
plt.hist(dataset1,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,alpha=0.5,bins=20)
# Out:
# (array([ 3.,  1.,  2.,  2.,  5.,  4.,  7.,  3.,  4., 11.,  8., 10.,  9.,
#          2.,  5.,  2.,  1.,  0.,  0.,  1.]),
#  array([-2.49345746, -2.22855969, -1.96366193, -1.69876416, -1.43386639,
#         -1.16896863, -0.90407086, -0.63917309, -0.37427532, -0.10937756,
#          0.15552021,  0.42041798,  0.68531574,  0.95021351,  1.21511128,
#          1.48000904,  1.74490681,  2.00980458,  2.27470235,  2.53960011,
#          2.80449788]),
#  <a list of 20 Patch objects>)

# %%
# Figures and Subplots
fig = plt.figure()

# %%
fig = plt.figure(figsize = (2,4), dpi=100)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot([1.5,3.5,-2,1.6])

# %%
fig = plt.figure( figsize = (5,5), dpi=100) # where each inch is represented by 100 pixels
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot([1.5,3.5,-2,1.6])

# %%
dataset = randn(50).cumsum()
dataset
# Out:
# array([ 0.51071801,  1.60204747,  1.81282449,  2.4992075 ,  2.77959745,
#         2.940296  ,  2.68475772,  3.65814868,  4.61005653,  5.71207239,
#         3.73856853,  4.12779541,  3.52647753,  4.3581383 ,  5.2670223 ,
#         5.70406294,  5.77777826,  6.78544857,  7.32684566,  8.39797401,
#         9.5714798 ,  9.30197739,  8.83315078,  8.52630852,  8.8191981 ,
#         7.17368238,  8.11062626,  6.81716174,  7.27596252,  7.35193043,
#         7.00491915,  7.25485498,  6.81264249,  8.01651531,  7.1331335 ,
#         7.8322079 ,  9.888361  ,  8.86797481, 11.27229003, 12.3356069 ,
#        11.01745158, 10.47069353, 11.09139877, 10.89238509, 12.8657843 ,
#        13.22830908, 12.54997496, 11.47356404, 11.51266305, 11.76450449])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot(dataset, 'k--')

# %%
# Figure Axis
fig = plt.figure()

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,.4,.4))

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,.4,.4))
ax2 = fig1.add_axes((0.25,0.25,.3,.3))

# %%
fig2= plt.figure()
ax1 = fig2.add_axes((0,0,.4,.4))
ax2 = fig2.add_axes((0,0.7,.4,.4))

# %%
fig3= plt.figure()
ax1 = fig3.add_subplot(2,1,1)
ax2 = fig3.add_subplot(2,1,2)
plt.plot(dataset, 'k--')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot(dataset, 'k--')

# %%
#plot data inside a subplot
ax1.hist(randn(100), bins=20, color='k', alpha=0.8)
ax2.scatter(np.arange(30),randn(30).cumsum())#ax2.scatter(x,y)
fig

# %%
# Colors, Markers, and Line Styles
plt.plot(4 * randn(30),'ko--')

# %%
plt.plot(4 * randn(30), color='k', linestyle='dashed', marker='o')

# %%
data = randn(30).cumsum()
data
# Out:
# array([ 1.88525891,  2.37110238,  0.27794949, -0.14276446, -0.45010154,
#        -1.48771026, -2.93437952, -1.83018549, -2.31881061, -2.5268414 ,
#        -2.65840684, -2.91493177, -2.36608872, -1.47005809, -0.24158856,
#        -1.65531964, -2.9173361 , -2.51392055, -1.90536313, -0.54265368,
#        -1.04347202,  1.00369046,  1.40961298,  1.92267632,  3.17555197,
#         3.34865274,  2.06531287,  2.17394422,  1.76751152,  0.49478846])

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#            0
# 0   1.885259
# 1   2.371102
# 2   0.277949
# 3  -0.142764
# 4  -0.450102
# 5  -1.487710
# 6  -2.934380
# 7  -1.830185
# 8  -2.318811
# 9  -2.526841
# 10 -2.658407
# 11 -2.914932
# 12 -2.366089
# 13 -1.470058
# 14 -0.241589
# 15 -1.655320
# 16 -2.917336
# 17 -2.513921
# 18 -1.905363
# 19 -0.542654
# 20 -1.043472
# 21  1.003690
# 22  1.409613
# 23  1.922676
# 24  3.175552
# 25  3.348653
# 26  2.065313
# 27  2.173944
# 28  1.767512
# 29  0.494788

# %%
plt.plot(data)

# %%
plt.plot(data, drawstyle='steps-post')

# %%
plt.plot(data, 'k--')
plt.plot(data, 'k-', drawstyle='steps-post')

# %%
#using labels 
plt.plot(data, 'k--', label='Dashed-Line')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
d = {'col1': [1,2,4,3,2,1,6,7,3,9], 'col2': [5,8,9,10,12,8,6,2,8,7]}
df2 = pd.DataFrame(d)
df2
# Out:
#    col1  col2
# 0     1     5
# 1     2     8
# 2     4     9
# 3     3    10
# 4     2    12
# 5     1     8
# 6     6     6
# 7     7     2
# 8     3     8
# 9     9     7

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(df2['col1'],'k.', label='col1')
ax.plot(df2['col2'], 'ko--', label='col2')
ax.legend(loc='best')

# %%
#DataFrame plotting
df2['col1'].plot.bar()

# %%
df2['col2'].plot.bar()

# %%
#Ticks, Labels, and Legends
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0, 250,500,750,1000])

labels = ax.set_xticklabels(['one','two','three','four','five'], rotation=30, fontsize='small')

ax.set_title('My First Matplotlip Plot with Ticks')

ax.set_xlabel('Stages')
ax.set_ylabel('Values')

fig

# %%
props ={'title': 'My First Matplotlip Plot with Ticks',
        'xlabel': 'Stages',
        'ylabel': 'Values'}

ax.set(**props)
fig

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(), 'k-', label='One')
ax.plot(randn(1000).cumsum(), 'k--', label='Two')
ax.plot(randn(1000).cumsum(), 'k.', label='Three')

ax.legend(loc='best')

# %%
#saving a figure in an image file
fig.savefig('fig1.png')
